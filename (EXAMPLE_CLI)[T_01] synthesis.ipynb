# %% [markdown]
# ## import

# %%
import os
import torch

from synthesize import *

os.environ["CUDA_VISIBLE_DEVICES"]="2"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Current Path

# %%
# %pwd
# Out:
# '/home/heiscold/fastspeech2'

# %% [markdown]
# ## Synthesize in CLI

# %%
# !python synthesize.py --raw_texts "Google is one of the companies I want to join." --restore_step 100000
# Out:
# cuda
# 100000Model Loaded
# Using cache found in /home/heiscold/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub
# /home/heiscold/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/common.py:13: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# /home/heiscold/.cache/torch/hub/NVIDIA_DeepLearningExamples_torchhub/PyTorch/Classification/ConvNets/image_classification/models/efficientnet.py:17: UserWarning: pytorch_quantization module not found, quantization will not be available
#   warnings.warn(
# HiFi-GAN: Removing weight norm.
# DownLoaded | NVIDIA's HiFi-GAN from torch hub | SR: 22050
# Vocoder Downloaded
# CONTROL VALUES: (1.0, 1.0, 1.0)
# Accelerate Prepared:
# Raw Text Sequence: Google is one of the companies I want to join
# Phoneme Sequence: {G UW1 G AH0 L IH0 Z HH W AH1 N AH0 V DH AH0 K AH1 M P AH0 N IY0 Z AY1 W AA1 N T T AH0 JH OY1 N}
# ...

# %%
raw_texts = "Google is one of the companies I want to join."
ids = raw_texts[0] # raw_texts "Google is one of the companies I want to join."

# Saved Paths: AUDIO, MEL SAVE PATH
result_path = "/home/heiscold/fastspeech2/result/ljspeech/t_01"
# Synthesized wav, png files' saved_dir

audio_result_path = result_path+ f"/{ids}.wav"
mel_result_path = result_path + f"/{ids}.png"

# %%
print(f"SENTENCE: {raw_texts}")
sample_rate = 22050
print(audio_result_path)
ipd.display(ipd.Audio(audio_result_path, rate =sample_rate)) 

print(mel_result_path)
Image.open(mel_result_path).convert("RGB")
# Out:
# SENTENCE: Google is one of the companies I want to join.
# /home/heiscold/fastspeech2/result/ljspeech/t_01/G.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# /home/heiscold/fastspeech2/result/ljspeech/t_01/G.png
# <PIL.Image.Image image mode=RGB size=640x480>
